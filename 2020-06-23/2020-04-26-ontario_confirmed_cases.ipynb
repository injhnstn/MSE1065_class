# %% [markdown]
# # Ontario confirmed COVID-19 cases per Region
# > "Map and graphs of confirmed COVID-19 cases in Ontario, Canada"
#
# - author: Sophiah Ho https://github.com/anomal
# - categories: [ontario, canada, covid-19, province, toronto, waterloo, ottawa, peel, york region, halton, sudbury]
# - image: images/ontario_confirmed_map.png
# - permalink: /ontario-confirmed-cases-per-region/

# %% [markdown]
# This workbook demonstrates the use of plotting and data exploration in python using plotly library. We will visualize the number of confirmed COVID-19 cases in Ontario as based in different regions

# %%
#hide
import urllib, json
import pandas as pd
#import plotly.graph_objects as go
#import plotly.express as px
from IPython.display import HTML

# We are obtaining data from this URL and storing it in pandas dataframe

url = 'https://data.ontario.ca/en/api/3/action/datastore_search?resource_id=455fd63b-603d-4608-8216-7d8647f43350&limit=9999999'  
fileobj = urllib.request.urlopen(url)
vals = json.load(fileobj)
df = pd.DataFrame(data=vals["result"]["records"])
df
# Out:
#          _id  Row_ID Accurate_Episode_Date   Case_Reported_Date  \
# 0          1       1   2020-03-18T00:00:00  2020-03-31T00:00:00
# 1          2       2   2020-03-23T00:00:00  2020-03-30T00:00:00
# 2          3       3   2020-03-27T00:00:00  2020-03-31T00:00:00
# 3          4       4   2020-03-27T00:00:00  2020-03-31T00:00:00
# 4          5       5   2020-03-22T00:00:00  2020-03-31T00:00:00
# ...      ...     ...                   ...                  ...
# 33848  33848   33848   2020-04-11T00:00:00  2020-04-17T00:00:00
# 33849  33849   33849   2020-04-02T00:00:00  2020-04-18T00:00:00
# 33850  33851   33851   2020-04-16T00:00:00  2020-04-17T00:00:00
# 33851  33852   33852   2020-04-09T00:00:00  2020-04-17T00:00:00
# 33852  33853   33853   2020-04-14T00:00:00  2020-04-16T00:00:00
#
#         Test_Reported_Date        Specimen_Date Age_Group Client_Gender  \
# 0      2020-03-31T00:00:00  2020-03-20T00:00:00       50s          MALE
# 1      2020-03-31T00:00:00  2020-03-30T00:00:00       70s        FEMALE
# 2      2020-03-30T00:00:00  2020-03-30T00:00:00       20s        FEMALE
# 3      2020-03-31T00:00:00  2020-03-30T00:00:00       40s        FEMALE
# 4      2020-03-31T00:00:00  2020-03-28T00:00:00       70s        FEMALE
# ...                    ...                  ...       ...           ...
# 33848  2020-04-17T00:00:00  2020-04-16T00:00:00       60s          MALE
# 33849  2020-04-18T00:00:00  2020-04-15T00:00:00       60s          MALE
# 33850  2020-04-17T00:00:00  2020-04-16T00:00:00       30s          MALE
# 33851  2020-04-17T00:00:00  2020-04-10T00:00:00       70s        FEMALE
# 33852  2020-04-16T00:00:00  2020-04-14T00:00:00       80s       UNKNOWN
#
#       Case_AcquisitionInfo  Outcome1 Outbreak_Related  \
# 0                   Travel  Resolved
# 1              No Epi-link  Resolved
# 2              No Epi-link  Resolved
# 3              No Epi-link  Resolved
# 4                   Travel  Resolved
# ...                    ...       ...              ...
# 33848                   OB  Resolved              Yes
# 33849                   OB     Fatal              Yes
# 33850                   OB  Resolved              Yes
# 33851                   OB  Resolved              Yes
# 33852                   OB     Fatal              Yes
#
#                            Reporting_PHU           Reporting_PHU_Address  \
# 0                   Ottawa Public Health         100 Constellation Drive
# 1       Windsor-Essex County Health Unit           1005 Ouellette Avenue
# 2       Windsor-Essex County Health Unit           1005 Ouellette Avenue
# 3      Region of Waterloo, Public Health          99 Regina Street South
# 4                   Ottawa Public Health         100 Constellation Drive
# ...                                  ...                             ...
# 33848  Region of Waterloo, Public Health          99 Regina Street South
# 33849                 Peel Public Health          7120 Hurontario Street
# 33850              Toronto Public Health  277 Victoria Street, 5th Floor
# 33851                 Peel Public Health          7120 Hurontario Street
# 33852              Toronto Public Health  277 Victoria Street, 5th Floor
#
#       Reporting_PHU_City Reporting_PHU_Postal_Code  \
# 0                 Ottawa                   K2G 6J8
# 1                Windsor                   N9A 4J8
# 2                Windsor                   N9A 4J8
# 3               Waterloo                   N2J 4V3
# 4                 Ottawa                   K2G 6J8
# ...                  ...                       ...
# 33848           Waterloo                   N2J 4V3
# 33849        Mississauga                   L5W 1N4
# 33850            Toronto                   M5B 1W2
# 33851        Mississauga                   L5W 1N4
# 33852            Toronto                   M5B 1W2
#
#                                    Reporting_PHU_Website  \
# 0                              www.ottawapublichealth.ca
# 1                                          www.wechu.org
# 2                                          www.wechu.org
# 3                                www.regionofwaterloo.ca
# 4                              www.ottawapublichealth.ca
# ...                                                  ...
# 33848                            www.regionofwaterloo.ca
# 33849                          www.peelregion.ca/health/
# 33850  www.toronto.ca/community-people/health-wellnes...
# 33851                          www.peelregion.ca/health/
# 33852  www.toronto.ca/community-people/health-wellnes...
#
#        Reporting_PHU_Latitude  Reporting_PHU_Longitude
# 0                   45.345665               -75.763912
# 1                   42.308796               -83.033670
# 2                   42.308796               -83.033670
# 3                   43.462876               -80.520913
# 4                   45.345665               -75.763912
# ...                       ...                      ...
# 33848               43.462876               -80.520913
# 33849               43.647471               -79.708893
# 33850               43.656591               -79.379358
# 33851               43.647471               -79.708893
# 33852               43.656591               -79.379358
#
# [33853 rows x 18 columns]

# %% [markdown]
# The dataframe has number of attrbutes including age_group, reporting public health unit and address of PHU. Our visualization will use these attributes along with date of reporting.

# %%
#hide
import dateutil.parser

# Following is the range of dates we want to visualize the data
mindate = "2020-03-01" #dateutil.parser.parse(df["Accurate_Episode_Date"].min()).date()
maxdate = "2020-05-01" #dateutil.parser.parse(df["Accurate_Episode_Date"].max()).date()

# %%
#hide_input
HTML(f"Data is available for the period from {str(mindate)} to {str(maxdate)}.")
# Out:
# Data is available for the period from 2020-03-01 to 2020-05-01.

# %%
#hide

# We will group the input data frame according to travel relted history and region
import re

traveldf = df[df["Case_AcquisitionInfo"] == "Travel-Related"] \
.groupby(["Accurate_Episode_Date", "Reporting_PHU", "Reporting_PHU_Latitude", "Reporting_PHU_Longitude"]) \
.count()["Row_ID"] \
.reset_index() \
.rename(columns={"Row_ID" : "Travelled_Count"}) 

countdf = df \
.groupby(["Accurate_Episode_Date", "Reporting_PHU", "Reporting_PHU_Latitude", "Reporting_PHU_Longitude"]) \
.count()["Row_ID"] \
.reset_index() \
.rename(columns={"Row_ID" : "Count"}) 
countdf

joindf = pd.merge(countdf, traveldf, how="left", \
left_on=["Accurate_Episode_Date", "Reporting_PHU", "Reporting_PHU_Latitude", "Reporting_PHU_Longitude"], \
right_on=["Accurate_Episode_Date", "Reporting_PHU", "Reporting_PHU_Latitude", "Reporting_PHU_Longitude"]) \
.fillna(0)
joindf["Datetime"] = joindf.apply(lambda row: dateutil.parser.parse(row["Accurate_Episode_Date"]), axis=1)

phus = countdf.groupby(by=["Reporting_PHU","Reporting_PHU_Latitude","Reporting_PHU_Longitude"], as_index=False) \
    .first()[["Reporting_PHU","Reporting_PHU_Latitude","Reporting_PHU_Longitude"]].to_dict("index")
dates = pd.date_range(mindate, maxdate).tolist()

for date in dates:
    for i in range(len(phus)):
        phu = phus[i]
        phu_name = phu["Reporting_PHU"]
        if joindf[(joindf["Datetime"] == date) & (joindf["Reporting_PHU"] == phu_name)].shape[0] == 0:
            joindf = joindf.append({"Datetime" : date, "Reporting_PHU" : phu_name, \
                          "Reporting_PHU_Latitude" : phu["Reporting_PHU_Latitude"], \
                          "Reporting_PHU_Longitude" : phu["Reporting_PHU_Longitude"], \
                          "Count" : 0, "Travelled_Count" : 0},ignore_index=True)
joindf["Date"] = joindf.apply(lambda row: str(row["Datetime"].date()), axis=1)

aggdf = joindf[["Date", "Reporting_PHU", "Reporting_PHU_Latitude", "Reporting_PHU_Longitude", \
                "Count", "Travelled_Count"]].sort_values(by=["Date","Reporting_PHU"]).reset_index(drop=True)

def cumulativeSum(df, phu, date):
    return df[(df["Reporting_PHU"] == phu) & (df["Date"] <= date)]["Count"].sum()

def cumulativeTravelled(df, phu, date):
    return df[(df["Reporting_PHU"] == phu) & (df["Date"] <= date)]["Travelled_Count"].sum()

def cumulativeNotTravelled(df, phu, date):
    return cumulativeSum(df, phu, date) - cumulativeTravelled(df, phu, date)

def cumulativePercentTravelled(df, phu, date):
    total = cumulativeSum(df, phu, date)
    if total != 0:
        totalTravelled = cumulativeTravelled(df, phu, date)
        return 100 * totalTravelled / total
    else:
        return 0

def getRegion(phu_name):
    return re.sub("(Health|Public|,).+$", "", phu_name)
    
aggdf["Total"] = aggdf.apply(lambda row: cumulativeSum(aggdf, row["Reporting_PHU"], row["Date"]), axis=1) 
aggdf["Total Travelled"] = aggdf.apply(lambda row: cumulativeTravelled(aggdf, row["Reporting_PHU"], row["Date"]), axis=1) 
aggdf["Total Not Travelled"] = aggdf.apply(lambda row: cumulativeNotTravelled(aggdf, row["Reporting_PHU"], row["Date"]), axis=1) 
aggdf["Total Percent Travelled"] = aggdf.apply(lambda row: cumulativePercentTravelled(aggdf, row["Reporting_PHU"], row["Date"]), axis=1)
aggdf["Region"] = aggdf.apply(lambda row: getRegion(row["Reporting_PHU"]), axis=1)
aggdf
# Out:
#             Date                        Reporting_PHU  Reporting_PHU_Latitude  \
# 0     2020-01-01        Haldimand-Norfolk Health Unit               42.847825
# 1     2020-01-01    Region of Waterloo, Public Health               43.462876
# 2     2020-01-21                Toronto Public Health               43.656591
# 3     2020-01-22                Toronto Public Health               43.656591
# 4     2020-01-24         Middlesex-London Health Unit               42.981468
# ...          ...                                  ...                     ...
# 3075  2020-06-21     Windsor-Essex County Health Unit               42.308796
# 3076  2020-06-21   York Region Public Health Services               44.048023
# 3077  2020-06-22                   Peel Public Health               43.647471
# 3078  2020-06-22  Simcoe Muskoka District Health Unit               44.410713
# 3079  2020-06-22   York Region Public Health Services               44.048023
#
#       Reporting_PHU_Longitude  Count  Travelled_Count  Total  Total Travelled  \
# 0                  -80.303815      1              0.0      1              0.0
# 1                  -80.520913      1              0.0      1              0.0
# 2                  -79.379358      1              0.0      1              0.0
# 3                  -79.379358      1              0.0      2              0.0
# 4                  -81.254016      1              0.0      1              0.0
# ...                       ...    ...              ...    ...              ...
# 3075               -83.033670      2              0.0   1352              0.0
# 3076               -79.480239      1              0.0   2847              0.0
# 3077               -79.708893      3              0.0   5542              0.0
# 3078               -79.686306      2              0.0    572              0.0
# 3079               -79.480239      1              0.0   2848              0.0
#
#       Total Not Travelled  Total Percent Travelled                    Region
# 0                     1.0                      0.0        Haldimand-Norfolk
# 1                     1.0                      0.0        Region of Waterloo
# 2                     1.0                      0.0                  Toronto
# 3                     2.0                      0.0                  Toronto
# 4                     1.0                      0.0         Middlesex-London
# ...                   ...                      ...                       ...
# 3075               1352.0                      0.0     Windsor-Essex County
# 3076               2847.0                      0.0              York Region
# 3077               5542.0                      0.0                     Peel
# 3078                572.0                      0.0  Simcoe Muskoka District
# 3079               2848.0                      0.0              York Region
#
# [3080 rows x 11 columns]

# %%
#hide
# Sorting by the number of COVID-19 cases as of May 1st, 2020
latestdf = aggdf[aggdf["Date"] == str(maxdate)].sort_values(by=["Count"])
latestdf
# Out:
#             Date                                      Reporting_PHU  \
# 2116  2020-05-01                          Algoma Public Health Unit
# 2138  2020-05-01                              Porcupine Health Unit
# 2143  2020-05-01                     Sudbury & District Health Unit
# 2144  2020-05-01                   Thunder Bay District Health Unit
# 2134  2020-05-01                           Northwestern Health Unit
# 2145  2020-05-01                            Timiskaming Health Unit
# 2127  2020-05-01                   Huron Perth District Health Unit
# 2126  2020-05-01    Hastings and Prince Edward Counties Health Unit
# 2128  2020-05-01  Kingston, Frontenac and Lennox & Addington Pub...
# 2140  2020-05-01            Renfrew County and District Health Unit
# 2123  2020-05-01  Haliburton, Kawartha, Pine Ridge District Heal...
# 2142  2020-05-01                         Southwestern Public Health
# 2129  2020-05-01                              Lambton Public Health
# 2130  2020-05-01   Leeds, Grenville and Lanark District Health Unit
# 2121  2020-05-01                             Grey Bruce Health Unit
# 2133  2020-05-01         North Bay Parry Sound District Health Unit
# 2118  2020-05-01                           Chatham-Kent Health Unit
# 2137  2020-05-01                         Peterborough Public Health
# 2117  2020-05-01                           Brant County Health Unit
# 2131  2020-05-01                       Middlesex-London Health Unit
# 2124  2020-05-01                    Halton Region Health Department
# 2122  2020-05-01                      Haldimand-Norfolk Health Unit
# 2120  2020-05-01                        Eastern Ontario Health Unit
# 2147  2020-05-01           Wellington-Dufferin-Guelph Public Health
# 2125  2020-05-01                    Hamilton Public Health Services
# 2132  2020-05-01            Niagara Region Public Health Department
# 2148  2020-05-01                   Windsor-Essex County Health Unit
# 2139  2020-05-01                  Region of Waterloo, Public Health
# 2141  2020-05-01                Simcoe Muskoka District Health Unit
# 2119  2020-05-01                    Durham Region Health Department
# 2135  2020-05-01                               Ottawa Public Health
# 2149  2020-05-01                 York Region Public Health Services
# 2136  2020-05-01                                 Peel Public Health
# 2146  2020-05-01                              Toronto Public Health
#
#       Reporting_PHU_Latitude  Reporting_PHU_Longitude  Count  Travelled_Count  \
# 2116               46.532373               -84.314836      0              0.0
# 2138               48.472510               -81.328750      0              0.0
# 2143               46.466092               -80.998059      0              0.0
# 2144               48.400572               -89.258851      0              0.0
# 2134               49.769615               -94.488254      0              0.0
# 2145               47.509284               -79.681632      0              0.0
# 2127               43.368662               -81.001913      0              0.0
# 2126               44.186674               -77.391446      0              0.0
# 2128               44.227874               -76.525211      0              0.0
# 2140               45.799406               -77.118727      0              0.0
# 2123               43.968173               -78.285792      1              0.0
# 2142               42.777804               -81.151156      1              0.0
# 2129               42.986416               -82.404808      1              0.0
# 2130               44.615843               -75.702833      1              0.0
# 2121               44.576196               -80.940980      1              0.0
# 2133               46.313207               -79.467840      1              0.0
# 2118               42.403861               -82.208561      1              0.0
# 2137               44.301632               -78.321347      1              0.0
# 2117               43.151811               -80.274374      1              0.0
# 2131               42.981468               -81.254016      2              0.0
# 2124               43.413997               -79.744796      2              0.0
# 2122               42.847825               -80.303815      3              0.0
# 2120               45.029152               -74.736298      4              0.0
# 2147               43.524881               -80.233743      5              0.0
# 2125               43.257631               -79.871341      6              0.0
# 2132               43.116537               -79.241220      7              0.0
# 2148               42.308796               -83.033670     12              0.0
# 2139               43.462876               -80.520913     19              0.0
# 2141               44.410713               -79.686306     19              0.0
# 2119               43.898605               -78.940341     22              0.0
# 2135               45.345665               -75.763912     24              0.0
# 2149               44.048023               -79.480239     25              0.0
# 2136               43.647471               -79.708893     94              0.0
# 2146               43.656591               -79.379358    187              0.0
#
#       Total  Total Travelled  Total Not Travelled  Total Percent Travelled  \
# 2116     14              0.0                 14.0                      0.0
# 2138     61              0.0                 61.0                      0.0
# 2143     59              0.0                 59.0                      0.0
# 2144     77              0.0                 77.0                      0.0
# 2134     17              0.0                 17.0                      0.0
# 2145     18              0.0                 18.0                      0.0
# 2127     50              0.0                 50.0                      0.0
# 2126     43              0.0                 43.0                      0.0
# 2128     60              0.0                 60.0                      0.0
# 2140     17              0.0                 17.0                      0.0
# 2123    154              0.0                154.0                      0.0
# 2142     64              0.0                 64.0                      0.0
# 2129    193              0.0                193.0                      0.0
# 2130    316              0.0                316.0                      0.0
# 2121     84              0.0                 84.0                      0.0
# 2133     19              0.0                 19.0                      0.0
# 2118     89              0.0                 89.0                      0.0
# 2137     72              0.0                 72.0                      0.0
# 2117    106              0.0                106.0                      0.0
# 2131    439              0.0                439.0                      0.0
# 2124    497              0.0                497.0                      0.0
# 2122    197              0.0                197.0                      0.0
# 2120    113              0.0                113.0                      0.0
# 2147    322              0.0                322.0                      0.0
# 2125    464              0.0                464.0                      0.0
# 2132    553              0.0                553.0                      0.0
# 2148    689              0.0                689.0                      0.0
# 2139    921              0.0                921.0                      0.0
# 2141    347              0.0                347.0                      0.0
# 2119   1116              0.0               1116.0                      0.0
# 2135   1547              0.0               1547.0                      0.0
# 2149   1893              0.0               1893.0                      0.0
# 2136   2949              0.0               2949.0                      0.0
# 2146   7090              0.0               7090.0                      0.0
#
#                                     Region
# 2116                               Algoma
# 2138                            Porcupine
# 2143                   Sudbury & District
# 2144                 Thunder Bay District
# 2134                         Northwestern
# 2145                          Timiskaming
# 2127                 Huron Perth District
# 2126  Hastings and Prince Edward Counties
# 2128                              Kingston
# 2140          Renfrew County and District
# 2123                            Haliburton
# 2142                         Southwestern
# 2129                              Lambton
# 2130                                 Leeds
# 2121                           Grey Bruce
# 2133       North Bay Parry Sound District
# 2118                         Chatham-Kent
# 2137                         Peterborough
# 2117                         Brant County
# 2131                     Middlesex-London
# 2124                        Halton Region
# 2122                    Haldimand-Norfolk
# 2120                      Eastern Ontario
# 2147           Wellington-Dufferin-Guelph
# 2125                             Hamilton
# 2132                       Niagara Region
# 2148                 Windsor-Essex County
# 2139                    Region of Waterloo
# 2141              Simcoe Muskoka District
# 2119                        Durham Region
# 2135                               Ottawa
# 2149                          York Region
# 2136                                 Peel
# 2146                              Toronto

# %%
#hide_input

# Plotting the cumulative cases in ontario upto May 1st, 2020
import plotly.graph_objects as go
import plotly.express as px
prefix = "Cumulative Confirmed Cases per Ontario Region"
titlelatest = prefix + " up to " + str(maxdate)

latestdfdesc = latestdf.sort_values(by=["Total", "Total Not Travelled"], ascending=[False,False]).reset_index()

barfig = go.Figure(go.Bar(x=latestdfdesc["Region"], y=latestdfdesc["Total Travelled"], name='Travel-Related'))
barfig.add_trace(go.Bar(x=latestdfdesc["Region"], y=latestdfdesc["Total Not Travelled"], name='Other/Unknown'))
barfig.update_layout(barmode='stack', xaxis={'categoryorder':'array'}, title=titlelatest)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-f1ff714745c6> in <module>
#       2
#       3 # Plotting the cumulative cases in ontario upto May 1st, 2020
# ----> 4 import plotly.graph_objects as go
#       5 import plotly.express as px
#       6 prefix = "Cumulative Confirmed Cases per Ontario Region"
#
# ModuleNotFoundError: No module named 'plotly'

# %%
#hide_input
HTML("For the graphs below, the date used is integrated Public Health Information System (iPHIS)'s best estimated date of COVID-19 disease onset, projected into the past based on factors such as symptom onset, test date, or reported date.")

# %%
#hide_input

# Plot of confirmed cases. Color coding is the 
startdate = "2020-03-01"
fromto = "from " + startdate + " to " + str(maxdate)
agdfOne = aggdf[aggdf["Date"] >= startdate]
agdf = agdfOne[agdfOne["Date"]<= maxdate]
fig = px.scatter_mapbox(agdf, lat="Reporting_PHU_Latitude", lon="Reporting_PHU_Longitude",     
                        color="Total Percent Travelled", 
                        animation_frame="Date",
                        size="Total", hover_name="Reporting_PHU",
                        color_continuous_scale=[ "red","blue"], 
                        size_max=40, zoom=6, 
                        title="Cumulative Cases per Region over Time " + fromto,
                       center=dict(lat=43.6,lon=-79.7))
fig.update_layout(mapbox_style="open-street-map")
fig.show()

# %%
import numpy as np
np.min(agdfOne["Total Percent Travelled"])

# %%
#hide_input
# Plot of confirmed cases as per each county
cumline = px.line(agdf, x="Date", y="Total", color="Region", title=prefix + " " + fromto,
        labels={'Region':'Public Health Unit'}
)
cumline.show()

# %%
#hide_input
# Plot of daily confirmed cases as per each county
dailyline = px.line(agdf, x="Date", y="Count", color="Region", title="Daily Confirmed Cases per Ontario Region " + fromto,
       labels={'Region':'Public Health Unit'}
       )
dailyline.show()

# %%
#hide_input
from datetime import date
HTML(f'Data was last retrieved from <a href="https://data.ontario.ca/en/dataset/confirmed-positive-cases-of-covid-19-in-ontario/resource/455fd63b-603d-4608-8216-7d8647f43350" title="Ontario data">Confirmed positive cases of COVID19 in Ontario</a> on {str(date.today())}.')
